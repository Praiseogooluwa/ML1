# %% [markdown]
# ## API
# Stands for Application programming interface: it allows different software that are built differently to communicate with one another.
# - Work in a server client mode
# - Json is the end product of the request
# - REST: This is the means of communication, done through the web
# - GET: used to request data
# - POST: used to write data to the server(new data)
# - DELETE: delete data
# - PUT: write(update data)
#
# https://api.stackexchange.com/

# %%
import requests
import json
import pandas as pd

# %%
response = requests.get("https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow")

# %%
print(response)
# Out:
# <Response [200]>

# %%
response.json()["items"]
# Out:
# [{'tags': ['android', 'broadcastreceiver', 'activitynotfoundexception'],
#   'owner': {'account_id': 7093984,
#    'reputation': 45,
#    'user_id': 5428262,
#    'user_type': 'registered',
#    'accept_rate': 60,
#    'profile_image': 'https://lh5.googleusercontent.com/-ARDs-ZW9-Ao/AAAAAAAAAAI/AAAAAAAAAAs/hJzQ6fdYAAU/photo.jpg?sz=256',
#    'display_name': 'Noh Kumado',
#    'link': 'https://stackoverflow.com/users/5428262/noh-kumado'},
#   'is_answered': True,
#   'view_count': 578,
#   'accepted_answer_id': 41676785,
#   'answer_count': 1,
#   'score': 1,
#   'last_activity_date': 1719842660,
#   'creation_date': 1484570578,
#   'last_edit_date': 1719842660,
#   'question_id': 41676693,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/41676693/android-activity-not-found-exception-and-broadcastreceiver',
#   'title': 'Android Activity Not Found Exception and BroadcastReceiver'},
#  {'tags': ['ios', 'swift', 'xcode', 'drag-and-drop'],
# ...

# %%
pd.DataFrame(response.json()["items"])
# Out:
#                                                  tags  \
# 0   [android, broadcastreceiver, activitynotfounde...
# 1                  [ios, swift, xcode, drag-and-drop]
# 2                                [r, dplyr, group-by]
# 3            [java, arrays, string, function, object]
# 4        [python, r, apache-spark, pyspark, sparklyr]
# 5                                   [html, hyperlink]
# 6                                        [r, rstudio]
# 7          [ios, swift, watchkit, watchos, wcsession]
# 8   [c#, entity-framework-core, entity-framework-m...
# 9                       [xml, batch-file, sharepoint]
# 10         [c#, opencv, cuda, emgucv, compute-shader]
# 11  [javascript, node.js, database, mongodb, aggre...
# 12                                     [python, yaml]
# 13  [excel, flutter, dart, currency, number-format...
# 14        [python, pandas, dataframe, sorting, merge]
# 15                                          [ansible]
# ...

# %%
for data in response.json()["items"]:
    print(data["title"])
    print(data["link"])
    print()
# Out:
# Connecting to localhost via iPhone while connected to a hotspot
# https://stackoverflow.com/questions/63238084/connecting-to-localhost-via-iphone-while-connected-to-a-hotspot
#
# Rust Error: expected one of: `struct`, `enum`, `union`rust-analyzermacro-error
# https://stackoverflow.com/questions/78689857/rust-error-expected-one-of-struct-enum-unionrust-analyzermacro-error
#
# Error in Azure logic app workflow when using inline java script action
# https://stackoverflow.com/questions/77449921/error-in-azure-logic-app-workflow-when-using-inline-java-script-action
#
# Move the color and size table to be underneath the tilte of propduct. (Mobile Version)
# https://stackoverflow.com/questions/78689856/move-the-color-and-size-table-to-be-underneath-the-tilte-of-propduct-mobile-ve
#
# Tkinter how to destroy Frame that is created from another class and used in the main class?
# ...

# %%
my_key = "sdGnEK4oZ4tCUWlfGr8VqEva3w0RJESfRaJr0ZuN"
date = "2024-06-30"
concept_tags=True

# %%
response = requests.get(f"https://api.nasa.gov/planetary/apod?api_key={my_key}&{date}&{concept_tags}")

# %%
response.json()
# Out:
# {'code': 400,
#  'msg': "Bad Request: incorrect field passed. Allowed request fields for apod method are 'concept_tags', 'date', 'hd', 'count', 'start_date', 'end_date', 'thumbs'",
#  'service_version': 'v1'}

# %%
import webbrowser
import urllib.request

# %%
##Define APOD
apodurl = "https://api.nasa.gov/planetary/apod?"
mykey = "api_key=sdGnEK4oZ4tCUWlfGr8VqEva3w0RJESfRaJr0ZuN"

# %%
# call the webservice
apodurlobj = urllib.request.urlopen(apodurl + mykey)

# %%
## read the file-like object
apodread = apodurlobj.read()

# %%
apodread
# Out:
# b'{"date":"2024-06-30","explanation":"About 12 seconds into this video, something unusual happens. The Earth begins to rise.  Never seen by humans before, the rise of the Earth over the limb of the Moon occurred about 55.5 years ago and surprised and amazed the crew of Apollo 8. The crew immediately scrambled to take still images of the stunning vista caused by Apollo 8\'s orbit around the Moon. The featured video is a modern reconstruction of the event as it would have looked were it recorded with a modern movie camera. The colorful orb of our Earth stood out as a familiar icon rising above a distant and unfamiliar moonscape, the whole scene the conceptual reverse of a more familiar moonrise as seen from Earth. To many, the scene also spoke about the unity of humanity: that big blue marble -- that\'s us -- we all live there. The two-minute video is not time-lapse -- this is the real speed of the Earth rising through the windows of Apollo 8. Seven months and three missions later, Apo
# ...

# %%
# decode json to python data structure
decodeapod = json.loads(apodread.decode("utf-8"))

# %%
# display the python data
print("\n\nConverted python data")
print(decodeapod)
# Out:
# Converted python data
# ...

# %%
# Use firefox to open the HTTPS
input("\nPress Enter to open NASA Picture of the Day in Firefox")
webbrowser.open(decodeapod["url"])
# Out:
# Press Enter to open NASA Picture of the Day in Firefox
# True
